# %% [markdown]
# ##  Python Built in Data Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df1 = pd.read_csv('D:/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df1.csv',index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('D:/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df2.csv')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot.area(alpha=0.4)
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='A',y='B',c='C')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df2.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df3 = pd.read_csv('D:/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df3.csv')
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.plot.scatter(x='a',y='b',s=50,color='red',figsize=(12,3))
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df3['a'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(bins=20,alpha=0.6)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df3[['a','b']].plot.box()
# Out:
# <Axes: >

# %%
df3['d'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df3['d'].plot.kde(lw=5,ls='--')
# Out:
# <Axes: ylabel='Density'>

# %%
df3.plot.area(alpha=0.4)
# Out:
# <Axes: >

# %%
df3[0:30].plot.area(alpha=0.5)
# Out:
# <Axes: >

# %%
fig = plt.figure()
df3[0:30].plot.area(alpha=0.5)
plt.legend(loc='center left',bbox_to_anchor=(1.0,0.5))
