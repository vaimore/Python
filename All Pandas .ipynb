# %%
import plotly.express as px
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## Viewing and Inspecting Data

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0         0       3    male  22.0      1      0   7.2500        S   Third  \
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 881         0       3    male  33.0      0      0   7.8958        S   Third  \
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %%
df.shape
# Out:
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.values
# Out:
# array([[0, 3, 'male', ..., 'Southampton', 'no', False],
#        [1, 1, 'female', ..., 'Cherbourg', 'yes', False],
#        [1, 3, 'female', ..., 'Southampton', 'yes', True],
#        ...,
#        [0, 3, 'female', ..., 'Southampton', 'no', False],
#        [1, 1, 'male', ..., 'Cherbourg', 'yes', True],
#        [0, 3, 'male', ..., 'Queenstown', 'no', True]], dtype=object)

# %%
print(type(df.index))
# Out:
# <class 'pandas.core.indexes.range.RangeIndex'>

# %%
print(type(df.columns))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
print(type(df.values))
# Out:
# <class 'numpy.ndarray'>

# %%
df.dtypes.value_counts()
# Out:
# object      5
# int64       4
# float64     2
# bool        2
# category    1
# category    1
# Name: count, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['pclass'].value_counts()
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['class'].apply(len)
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 886    6
# 887    5
# 888    5
# 889    5
# 890    5
# Name: class, Length: 891, dtype: int64

# %%
df['fare'].apply(np.sum)
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
df[['sex','age']]
# Out:
#         sex   age
# 0      male  22.0
# 1    female  38.0
# 2    female  26.0
# 3    female  35.0
# 4      male  35.0
# ..      ...   ...
# 886    male  27.0
# 887  female  19.0
# 888  female   NaN
# 889    male  26.0
# 890    male  32.0
#
# [891 rows x 2 columns]

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[1:4,['survived','sex','pclass']]
# Out:
#    survived     sex  pclass
# 1         1  female       1
# 2         1  female       3
# 3         1  female       1
# 4         0    male       3

# %%
df.iloc[0:5,0:6]
# Out:
#    survived  pclass     sex   age  sibsp  parch
# 0         0       3    male  22.0      1      0
# 1         1       1  female  38.0      1      0
# 2         1       3  female  26.0      0      0
# 3         1       1  female  35.0      1      0
# 4         0       3    male  35.0      0      0

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.nsmallest(3,'fare')
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked  class  who
# 179         0       3  male  36.0      0      0   0.0        S  Third  man  \
# 263         0       1  male  40.0      0      0   0.0        S  First  man
# 271         1       3  male  25.0      0      0   0.0        S  Third  man
#
#      adult_male deck  embark_town alive  alone
# 179        True  NaN  Southampton    no   True
# 263        True    B  Southampton    no   True
# 271        True  NaN  Southampton   yes   True

# %%
df.nlargest(3,'fare')
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class
# 258         1       1  female  35.0      0      0  512.3292        C  First  \
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
#
#        who  adult_male deck embark_town alive  alone
# 258  woman       False  NaN   Cherbourg   yes   True
# 679    man        True    B   Cherbourg   yes  False
# 737    man        True    B   Cherbourg   yes   True

# %%
df.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
df_2 = df.copy()
df_2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_2.rename(columns={'alive':'Alive','alone':'Alone'},inplace= True)
df_2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town Alive  Alone
# ...

# %%
# change all column names to lowercase
df_2.rename(columns={'alive':'Alive','alone':'Alone'},inplace= True)
df_2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town Alive  Alone
# ...

# %%
df_2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town Alive  Alone
# ...

# %%
df_2.isna()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class
# 0       False   False  False  False  False  False  False     False  False  \
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  Alive  Alone
# ...

# %%
df_2.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# Alive            0
# Alone            0
# dtype: int64

# %%
df_2.isna().sum().sum()
# Out:
# 869

# %%
df_2.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# Alive            0
# Alone            0
# dtype: int64

# %%
df_2['age'].notna().sum()
# Out:
# 714

# %%
df_2.notna().sum()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# Alive          891
# Alone          891
# dtype: int64

# %%
df_2.notnull().sum()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# Alive          891
# Alone          891
# dtype: int64

# %%
df_2.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 1           1       1  female  38.0      1      0  71.2833        C  First  \
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town Alive  Alone
# ...

# %%
df_2.dropna(axis=1)
# Out:
#      survived  pclass     sex  sibsp  parch     fare   class    who
# 0           0       3    male      1      0   7.2500   Third    man  \
# 1           1       1  female      1      0  71.2833   First  woman
# 2           1       3  female      0      0   7.9250   Third  woman
# 3           1       1  female      1      0  53.1000   First  woman
# 4           0       3    male      0      0   8.0500   Third    man
# ..        ...     ...     ...    ...    ...      ...     ...    ...
# 886         0       2    male      0      0  13.0000  Second    man
# 887         1       1  female      0      0  30.0000   First  woman
# 888         0       3  female      1      2  23.4500   Third  woman
# 889         1       1    male      0      0  30.0000   First    man
# 890         0       3    male      0      0   7.7500   Third    man
#
#      adult_male Alive  Alone
# 0          True    no  False
# 1         False   yes  False
# 2         False   yes   True
# 3         False   yes  False
# ...

# %%
df_2.set_index('pclass')
# Out:
#         survived     sex   age  sibsp  parch     fare embarked   class    who
# pclass
# 3              0    male  22.0      1      0   7.2500        S   Third    man  \
# 1              1  female  38.0      1      0  71.2833        C   First  woman
# 3              1  female  26.0      0      0   7.9250        S   Third  woman
# 1              1  female  35.0      1      0  53.1000        S   First  woman
# 3              0    male  35.0      0      0   8.0500        S   Third    man
# ...          ...     ...   ...    ...    ...      ...      ...     ...    ...
# 2              0    male  27.0      0      0  13.0000        S  Second    man
# 1              1  female  19.0      0      0  30.0000        S   First  woman
# 3              0  female   NaN      1      2  23.4500        S   Third  woman
# 1              1    male  26.0      0      0  30.0000        C   First    man
# 3              0    male  32.0      0      0   7.7500        Q   Third    man
#
# ...

# %%
nba["College"].fillna("No College", inplace = True)
# Out:
# 688

# %%
df_2['age'].fillna(df_2['age'].mean(),inplace= True)

# %%
df_2.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# Alive            0
# Alone            0
# dtype: int64

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  Alive        891 non-null    object
#  14  Alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df_2['embark_town'].fillna('No Town',inplace = True)
df_2
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked
# 0           0       3    male  22.000000      1      0   7.2500        S  \
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town Alive  Alone
# ...

# %%
df_2[df_2['embark_town'] == 'No Town']
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class
# 61          1       1  female  38.0      0      0  80.0      NaN  First  \
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town Alive  Alone
# 61   woman       False    B     No Town   yes   True
# 829  woman       False    B     No Town   yes   True

# %%
df[829:830]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class
# 829         1       1  female  62.0      0      0  80.0      NaN  First  \
#
#        who  adult_male deck embark_town alive  alone
# 829  woman       False    B         NaN   yes   True

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  891 non-null    object
#  13  Alive        891 non-null    object
#  14  Alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df_2
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked
# 0           0       3    male  22.000000      1      0   7.2500        S  \
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town Alive  Alone
# ...

# %%
df_2.replace('male',"Male",inplace = True)

# %%
df_2
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked
# 0           0       3    Male  22.000000      1      0   7.2500        S  \
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    Male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    Male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    Male  26.000000      0      0  30.0000        C
# 890         0       3    Male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town Alive  Alone
# ...

# %% [markdown]
# ## Filter, Sort & Groupby

# %%
df_2[df_2['fare'] < 10]
# Out:
#      survived  pclass     sex        age  sibsp  parch    fare embarked
# 0           0       3    Male  22.000000      1      0  7.2500        S  \
# 2           1       3  female  26.000000      0      0  7.9250        S
# 4           0       3    Male  35.000000      0      0  8.0500        S
# 5           0       3    Male  29.699118      0      0  8.4583        Q
# 12          0       3    Male  20.000000      0      0  8.0500        S
# ..        ...     ...     ...        ...    ...    ...     ...      ...
# 877         0       3    Male  19.000000      0      0  7.8958        S
# 878         0       3    Male  29.699118      0      0  7.8958        S
# 881         0       3    Male  33.000000      0      0  7.8958        S
# 884         0       3    Male  25.000000      0      0  7.0500        S
# 890         0       3    Male  32.000000      0      0  7.7500        Q
#
#      class    who  adult_male deck  embark_town Alive  Alone
# ...

# %%
df_2[(df_2['fare']<10) & (df_2['class'] == 'Third')]
# Out:
#      survived  pclass     sex        age  sibsp  parch    fare embarked
# 0           0       3    Male  22.000000      1      0  7.2500        S  \
# 2           1       3  female  26.000000      0      0  7.9250        S
# 4           0       3    Male  35.000000      0      0  8.0500        S
# 5           0       3    Male  29.699118      0      0  8.4583        Q
# 12          0       3    Male  20.000000      0      0  8.0500        S
# ..        ...     ...     ...        ...    ...    ...     ...      ...
# 877         0       3    Male  19.000000      0      0  7.8958        S
# 878         0       3    Male  29.699118      0      0  7.8958        S
# 881         0       3    Male  33.000000      0      0  7.8958        S
# 884         0       3    Male  25.000000      0      0  7.0500        S
# 890         0       3    Male  32.000000      0      0  7.7500        Q
#
#      class    who  adult_male deck  embark_town Alive  Alone
# ...

# %%
df.sort_values('fare',ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class
# 258         1       1  female  35.0      0      0  512.3292        C   First  \
# 737         1       1    male  35.0      0      0  512.3292        C   First
# 679         1       1    male  36.0      0      1  512.3292        C   First
# 88          1       1  female  23.0      3      2  263.0000        S   First
# 27          0       1    male  19.0      3      2  263.0000        S   First
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 633         0       1    male   NaN      0      0    0.0000        S   First
# 413         0       2    male   NaN      0      0    0.0000        S  Second
# 822         0       1    male  38.0      0      0    0.0000        S   First
# 732         0       2    male   NaN      0      0    0.0000        S  Second
# 674         0       2    male   NaN      0      0    0.0000        S  Second
#
# ...

# %%
df.sort_values(['age','fare'],ascending = [True,False])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 803         1       3    male  0.42      0      1   8.5167        C   Third  \
# 755         1       2    male  0.67      1      1  14.5000        S  Second
# 469         1       3  female  0.75      2      1  19.2583        C   Third
# 644         1       3  female  0.75      2      1  19.2583        C   Third
# 78          1       2    male  0.83      0      2  29.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 481         0       2    male   NaN      0      0   0.0000        S  Second
# 633         0       1    male   NaN      0      0   0.0000        S   First
# 674         0       2    male   NaN      0      0   0.0000        S  Second
# 732         0       2    male   NaN      0      0   0.0000        S  Second
# 815         0       1    male   NaN      0      0   0.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.groupby('sex').survived.value_counts()
# Out:
# sex     survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
df.groupby('sex').age.value_counts()
# Out:
# sex     age
# female  24.00    16
#         18.00    13
#         22.00    12
#         30.00    11
#         35.00     8
#                  ..
# male    6.00      1
#         0.92      1
#         0.67      1
#         0.42      1
#         80.00     1
# Name: count, Length: 145, dtype: int64

# %%
df_2.groupby('pclass')['survived'].mean().sort_values()
# Out:
# pclass
# 3    0.242363
# 2    0.472826
# 1    0.629630
# Name: survived, dtype: float64

# %%
df_2
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked
# 0           0       3    Male  22.000000      1      0   7.2500        S  \
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    Male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    Male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    Male  26.000000      0      0  30.0000        C
# 890         0       3    Male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town Alive  Alone
# ...

# %%
df_2.groupby('sex').survived.mean()
# Out:
# sex
# Male      0.188908
# female    0.742038
# Name: survived, dtype: float64

# %%
df_2.groupby('sex').survived.median()
# Out:
# sex
# Male      0.0
# female    1.0
# Name: survived, dtype: float64

# %%
df_2.groupby('sex').survived.std()
# Out:
# sex
# Male      0.391775
# female    0.438211
# Name: survived, dtype: float64

# %%
df_2.groupby('sex').survived.max()
# Out:
# sex
# Male      1
# female    1
# Name: survived, dtype: int64

# %%
df_2.groupby('sex').survived.mean()
# Out:
# sex
# Male      0.188908
# female    0.742038
# Name: survived, dtype: float64

# %%
 df.groupby('sex').agg({'survived': ['mean', 'min', 'max']})
# Out:
#         survived
#             mean min max
# sex
# female  0.742038   0   1
# male    0.188908   0   1

# %%
df.groupby('sex').agg({'survived':['mean'],'age':['mean']})
# Out:
#         survived        age
#             mean       mean
# sex
# female  0.742038  27.915709
# male    0.188908  30.726645

# %%
df_2.groupby(['sex', 'pclass'])['survived'].agg(['count', 'mean'])
# Out:
#                count      mean
# sex    pclass
# Male   1         122  0.368852
#        2         108  0.157407
#        3         347  0.135447
# female 1          94  0.968085
#        2          76  0.921053
#        3         144  0.500000

# %%
df.groupby('sex').embark_town.value_counts()
# Out:
# sex     embark_town
# female  Southampton    203
#         Cherbourg       73
#         Queenstown      36
# male    Southampton    441
#         Cherbourg       95
#         Queenstown      41
# Name: count, dtype: int64

# %%
df.groupby('embark_town').survived.value_counts()
# Out:
# embark_town  survived
# Cherbourg    1            93
#              0            75
# Queenstown   0            47
#              1            30
# Southampton  0           427
#              1           217
# Name: count, dtype: int64

# %%
df_2.groupby('pclass').survived.value_counts()
# Out:
# pclass  survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: count, dtype: int64

# %%
df_2.groupby('pclass')['survived'].agg(['count'])
# Out:
#         count
# pclass
# 1         216
# 2         184
# 3         491

# %%
df.groupby('sex').agg({'survived':['mean','std'],'age':['mean','max','min']})
# Out:
#         survived                  age
#             mean       std       mean   max   min
# sex
# female  0.742038  0.438211  27.915709  63.0  0.75
# male    0.188908  0.391775  30.726645  80.0  0.42

# %%
df_2
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked
# 0           0       3    Male  22.000000      1      0   7.2500        S  \
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    Male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    Male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    Male  26.000000      0      0  30.0000        C
# 890         0       3    Male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town Alive  Alone
# ...

# %%
df_2['Alive'].value_counts()
# Out:
# Alive
# no     549
# yes    342
# Name: count, dtype: int64

# %%
df_2['Alive'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df_2['Alive'].nunique()
# Out:
# 2

# %%
df_2.groupby('sex').agg({'survived':['mean','std'],'age':['mean','std','min','max','median'],'pclass':['mean']})
# Out:
#         survived                  age
#             mean       std       mean        std   min   max     median
# sex
# Male    0.188908  0.391775  30.505824  13.009478  0.42  80.0  29.699118  \
# female  0.742038  0.438211  28.216730  12.877543  0.75  63.0  29.699118
#
#           pclass
#             mean
# sex
# Male    2.389948
# female  2.159236

# %%
df_2
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked
# 0           0       3    Male  22.000000      1      0   7.2500        S  \
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    Male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    Male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    Male  26.000000      0      0  30.0000        C
# 890         0       3    Male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town Alive  Alone
# ...

# %%
df_2.pivot_table(index=['sex','pclass'],columns='embarked',values='survived',aggfunc='count')
# Out:
# embarked        C   Q    S
# sex    pclass
# Male   1       42   1   79
#        2       10   1   97
#        3       43  39  265
# female 1       43   1   48
#        2        7   2   67
#        3       23  33   88

# %%
df_2.pivot_table(index=['sex','pclass'],columns='embarked',values='survived')
# Out:
# embarked              C         Q         S
# sex    pclass
# Male   1       0.404762  0.000000  0.354430
#        2       0.200000  0.000000  0.154639
#        3       0.232558  0.076923  0.128302
# female 1       0.976744  1.000000  0.958333
#        2       1.000000  1.000000  0.910448
#        3       0.652174  0.727273  0.375000

# %%
df_2.pivot_table(index=['sex','pclass'],columns='embarked',values='age',aggfunc='mean').round()
# Out:
# embarked          C     Q     S
# sex    pclass
# Male   1       39.0  44.0  40.0
#        2       27.0  57.0  31.0
#        3       27.0  29.0  27.0
# female 1       35.0  33.0  32.0
#        2       19.0  30.0  30.0
#        3       19.0  28.0  24.0

# %%
df_2.groupby(['sex','pclass']).agg({'age':['mean']}).round()
# Out:
#                 age
#                mean
# sex    pclass
# Male   1       39.0
#        2       31.0
#        3       27.0
# female 1       34.0
#        2       29.0
#        3       24.0

# %%
df_2.groupby(['sex','pclass']).agg({'age':['count']}).round()
# Out:
#                 age
#               count
# sex    pclass
# Male   1        122
#        2        108
#        3        347
# female 1         94
#        2         76
#        3        144

# %%
df_2
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked
# 0           0       3    Male  22.000000      1      0   7.2500        S  \
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    Male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    Male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    Male  26.000000      0      0  30.0000        C
# 890         0       3    Male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town Alive  Alone
# ...

# %%
df_2.select_dtypes(include=np.number).corr().round(2)
# Out:
#           survived  pclass   age  sibsp  parch  fare
# survived      1.00   -0.34 -0.07  -0.04   0.08  0.26
# pclass       -0.34    1.00 -0.33   0.08   0.02 -0.55
# age          -0.07   -0.33  1.00  -0.23  -0.18  0.09
# sibsp        -0.04    0.08 -0.23   1.00   0.41  0.16
# parch         0.08    0.02 -0.18   0.41   1.00  0.22
# fare          0.26   -0.55  0.09   0.16   0.22  1.00

# %%
df_2.select_dtypes(include=np.number).mean().round(2)
# Out:
# survived     0.38
# pclass       2.31
# age         29.70
# sibsp        0.52
# parch        0.38
# fare        32.20
# dtype: float64

# %%
df_2.select_dtypes(include=np.number).std().round(2)
# Out:
# survived     0.49
# pclass       0.84
# age         13.00
# sibsp        1.10
# parch        0.81
# fare        49.69
# dtype: float64

# %%
df_2.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df_2.select_dtypes(include=np.number).median().round(2)
# Out:
# survived     0.00
# pclass       3.00
# age         29.70
# sibsp        0.00
# parch        0.00
# fare        14.45
# dtype: float64

# %%
df_2
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked
# 0           0       3    Male  22.000000      1      0   7.2500        S  \
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    Male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    Male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    Male  26.000000      0      0  30.0000        C
# 890         0       3    Male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town Alive  Alone
# ...

# %%
df_2[df_2['age'] > 50].groupby('sex').survived.value_counts()
# Out:
# sex     survived
# Male    0           41
#         1            6
# female  1           16
#         0            1
# Name: count, dtype: int64

# %%
df_2[df_2['age'] > 50].groupby(['sex','pclass']).agg({'survived':['value_counts']})
# Out:
#                            survived
#                        value_counts
# sex    pclass survived
# Male   1      0                  21
#               1                   5
#        2      0                  11
#               1                   1
#        3      0                   9
# female 1      1                  13
#        2      1                   2
#               0                   1
#        3      1                   1

# %%
df.groupby('sex').agg({'survived':['mean','std'],'age':['mean','max','min']})
# Out:
#         survived                  age
#             mean       std       mean   max   min
# sex
# female  0.742038  0.438211  27.915709  63.0  0.75
# male    0.188908  0.391775  30.726645  80.0  0.42

# %%
df_2[df_2['age'] > 50].groupby('sex').agg({'survived':['value_counts','mean','std']})
# Out:
#                 survived
#             value_counts      mean       std
# Male                 NaN  0.127660  0.337318
# (Male, 0)           41.0       NaN       NaN
# (Male, 1)            6.0       NaN       NaN
# female               NaN  0.941176  0.242536
# (female, 0)          1.0       NaN       NaN
# (female, 1)         16.0       NaN       NaN

# %%
df_2.groupby(['sex','embarked','pclass']).agg({'age':['count','sum','var','nunique','first','last','std','mean','median']})
# Out:
#                          age
#                        count          sum         var nunique      first
# sex    embarked pclass
# Male   C        1         42  1622.194706  213.392456      26  40.000000  \
#                 2         10   266.898235   94.428709       9  32.500000
#                 3         43  1160.004118   59.657323      20  29.699118
#        Q        1          1    44.000000         NaN       1  44.000000
#                 2          1    57.000000         NaN       1  57.000000
#                 3         39  1136.477941  151.446045      15  29.699118
#        S        1         79  3126.906765  210.977644      37  54.000000
#                 2         97  2986.723824  205.773171      43  29.699118
#                 3        265  7201.655000  111.961489      55  22.000000
# female C        1         43  1518.495588  154.577647      28  38.000000
#                 2          7   134.000000   75.809524       7  14.000000
# ...

# %%
df_2.groupby(['sex','embarked','pclass']).agg({'survived':['count','sum','var','nunique','first','last','std','mean']})
# Out:
#                        survived
#                           count sum       var nunique first last       std
# sex    embarked pclass
# Male   C        1            42  17  0.246806       2     0    1  0.496796  \
#                 2            10   2  0.177778       2     0    1  0.421637
#                 3            43  10  0.182724       2     0    0  0.427463
#        Q        1             1   0       NaN       1     0    0       NaN
#                 2             1   0       NaN       1     0    0       NaN
#                 3            39   3  0.072874       2     0    0  0.269953
#        S        1            79  28  0.231743       2     0    0  0.481397
#                 2            97  15  0.132088       2     1    0  0.363439
#                 3           265  34  0.112264       2     0    0  0.335058
# female C        1            43  42  0.023256       2     1    1  0.152499
#                 2             7   7  0.000000       1     1    1  0.000000
# ...
