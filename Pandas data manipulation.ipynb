# %%
import pandas as pd
df = pd.read_csv("E:/Vaibhav/Study_CS/Python/train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   891.000000  891.000000  891.000000  714.000000  891.000000  \
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.value_counts(dropna = False)
# Out:
# PassengerId  Survived  Pclass  Name                                      Sex     Age   SibSp  Parch  Ticket      Fare    Cabin  Embarked
# 1            0         3       Braund, Mr. Owen Harris                   male    22.0  1      0      A/5 21171   7.250   NaN    S           1
# 599          0         3       Boulos, Mr. Hanna                         male    NaN   0      0      2664        7.225   NaN    C           1
# 588          1         1       Frolicher-Stehli, Mr. Maxmillian          male    60.0  1      1      13567       79.200  B41    C           1
# 589          0         3       Gilinski, Mr. Eliezer                     male    22.0  0      0      14973       8.050   NaN    S           1
# 590          0         3       Murdlin, Mr. Joseph                       male    NaN   0      0      A./5. 3235  8.050   NaN    S           1
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.sort_values('Pclass',ascending = False)
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 511          512         0       3
# 500          501         0       3
# 501          502         0       3
# 502          503         0       3
# ..           ...       ...     ...
# 102          103         0       1
# 710          711         1       1
# 711          712         0       1
# 712          713         1       1
# 445          446         1       1
#
#                                                  Name     Sex   Age  SibSp
# 0                             Braund, Mr. Owen Harris    male  22.0      1  \
# 511                                 Webber, Mr. James    male   NaN      0
# 500                                  Calic, Mr. Petar    male  17.0      0
# 501                               Canavan, Miss. Mary  female  21.0      0
# 502                    O'Sullivan, Miss. Bridget Mary  female   NaN      0
# ..                                                ...     ...   ...    ...
# ...

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df['Pclass'].nunique()
# Out:
# 3

# %%
df.sort_values(['Pclass','SibSp'])
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex
# 6              7         0       1            McCarthy, Mr. Timothy J    male  \
# 11            12         1       1           Bonnell, Miss. Elizabeth  female
# 23            24         1       1       Sloper, Mr. William Thompson    male
# 30            31         0       1           Uruchurtu, Don. Manuel E    male
# 54            55         0       1     Ostby, Mr. Engelhart Cornelius    male
# ..           ...       ...     ...                                ...     ...
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
# ...

# %%
df.sort_values(['Pclass','SibSp'], ascending = [True,False])
# Out:
#      PassengerId  Survived  Pclass                                  Name
# 27            28         0       1        Fortune, Mr. Charles Alexander  \
# 88            89         1       1            Fortune, Miss. Mabel Helen
# 341          342         1       1        Fortune, Miss. Alice Elizabeth
# 245          246         0       1           Minahan, Dr. William Edward
# 311          312         1       1            Ryerson, Miss. Emily Borie
# ..           ...       ...     ...                                   ...
# 881          882         0       3                    Markun, Mr. Johann
# 882          883         0       3          Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                Sutehall, Mr. Henry Jr
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
# 890          891         0       3                   Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch           Ticket      Fare            Cabin
# ...

# %%
df.sort_values(['Pclass'])
# Out:
#      PassengerId  Survived  Pclass
# 445          446         1       1  \
# 310          311         1       1
# 309          310         1       1
# 307          308         1       1
# 306          307         1       1
# ..           ...       ...     ...
# 379          380         0       3
# 381          382         1       3
# 382          383         0       3
# 371          372         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 445                          Dodge, Master. Washington    male   4.0      0  \
# 310                     Hays, Miss. Margaret Bechstein  female  24.0      0
# 309                     Francatelli, Miss. Laura Mabel  female  30.0      0
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0      1
# 306                            Fleming, Miss. Margaret  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[:,:5]
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# ...

# %%
df[['SibSp','Pclass']]
# Out:
#      SibSp  Pclass
# 0        1       3
# 1        1       1
# 2        0       3
# 3        1       1
# 4        0       3
# ..     ...     ...
# 886      0       2
# 887      0       1
# 888      1       3
# 889      0       1
# 890      0       3
#
# [891 rows x 2 columns]

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df['Age'].nunique()
# Out:
# 88

# %%
df[df['Age'] > 40]
# Out:
#      PassengerId  Survived  Pclass
# 6              7         0       1  \
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 35            36         0       1
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp
# 6                              McCarthy, Mr. Timothy J    male  54.0      0  \
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Sex'] == 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex
# 0              1         0       3         Braund, Mr. Owen Harris  male  \
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
female = df[df['Sex'] == 'female']
female
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
male = df[df['Sex'] == 'male']
male
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex
# 0              1         0       3         Braund, Mr. Owen Harris  male  \
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
female.shape
# Out:
# (314, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Cabin'].nunique()
# Out:
# 147

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df['Ticket'].value_counts()
# Out:
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64

# %%
Ticket_7 = df['Ticket'] == '7'

# %%
Ticket_7
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Ticket, Length: 891, dtype: bool

# %%
cabin = df[['Cabin']] == 'G6'
cabin
# Out:
#      Cabin
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 886  False
# 887  False
# 888  False
# 889  False
# 890  False
#
# [891 rows x 1 columns]

# %%
df[df['Sex'] == 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex
# 0              1         0       3         Braund, Mr. Owen Harris  male  \
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df[df['Sex'] == 'male' & df['Embarked'] == 'S']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:311, in na_logical_op(x, y, op)
#     302 try:
#     303     # For exposition, write:
#     304     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     309     # Then Cases where this goes through without raising include:
#     310     #  (xint or xbool) and (yint or bool)
# --> 311     result = op(x, y)
#     312 except TypeError:
#
# File ~\anaconda3\lib\site-packages\pandas\core\roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
male
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex
# 0              1         0       3         Braund, Mr. Owen Harris  male  \
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
Embarked = df['Embarked'] == 'S'
Embarked
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Embarked, Length: 891, dtype: bool

# %%
Male1 = df['Sex'] == 'male'
Male1
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
df[Male1 & Embarked]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex
# 0              1         0       3         Braund, Mr. Owen Harris  male  \
# 4              5         0       3        Allen, Mr. William Henry  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# ..           ...       ...     ...                             ...   ...
# 878          879         0       3              Laleff, Mr. Kristo  male
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df[(df['Sex'] == 'male') & (df['Embarked'] == 'S')]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex
# 0              1         0       3         Braund, Mr. Owen Harris  male  \
# 4              5         0       3        Allen, Mr. William Henry  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# ..           ...       ...     ...                             ...   ...
# 878          879         0       3              Laleff, Mr. Kristo  male
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Ticket'].value_counts()
# Out:
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64

# %%
is_ticket = df['Ticket'].isin(['347082','1601'])
df[is_ticket]
# Out:
#      PassengerId  Survived  Pclass
# 13            14         0       3  \
# 74            75         1       3
# 119          120         0       3
# 169          170         0       3
# 509          510         1       3
# 541          542         0       3
# 542          543         0       3
# 610          611         0       3
# 643          644         1       3
# 692          693         1       3
# 813          814         0       3
# 826          827         0       3
# 838          839         1       3
# 850          851         0       3
#
#                                                   Name     Sex   Age  SibSp
# 13                         Andersson, Mr. Anders Johan    male  39.0      1  \
# 74                                       Bing, Mr. Lee    male  32.0      0
# 119                  Andersson, Miss. Ellis Anna Maria  female   2.0      4
# 169                                      Ling, Mr. Lee    male  28.0      0
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Fare'].sort_values()
# Out:
# 271      0.0000
# 597      0.0000
# 302      0.0000
# 633      0.0000
# 277      0.0000
#          ...
# 438    263.0000
# 341    263.0000
# 737    512.3292
# 258    512.3292
# 679    512.3292
# Name: Fare, Length: 891, dtype: float64

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop_duplicates(subset ="Pclass")
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C
# 9      0     237736  30.0708   NaN        C

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
df.groupby(["Sex",""])["Age"].agg([min,max,sum,])
# Out:
#          min   max       sum
# Sex
# female  0.75  63.0   7286.00
# male    0.42  80.0  13919.17

# %%
df_A = df[df['Sex'] == 'male']["Age"].mean()
df_A
# Out:
# 30.72664459161148

# %%
import numpy as np
df.groupby('Sex')[['Age','Pclass']].agg([np.min,np.max,np.mean,np.median])
# Out:
#          Age                         Pclass
#         amin  amax       mean median   amin amax      mean median
# Sex
# female  0.75  63.0  27.915709   27.0      1    3  2.159236    2.0
# male    0.42  80.0  30.726645   29.0      1    3  2.389948    3.0

# %%
df.pivot_table(values = "Pclass",index = "Sex")
# Out:
#           Pclass
# Sex
# female  2.159236
# male    2.389948

# %%
df.pivot_table(values="Pclass",index="Sex",aggfunc=[np.mean,np.median])
# Out:
#             mean median
#           Pclass Pclass
# Sex
# female  2.159236      2
# male    2.389948      3

# %%
df.pivot_table(values = 'Pclass', index = 'Sex', columns = 'Name')
# Out:
# Name    Abbing, Mr. Anthony  Abbott, Mr. Rossmore Edward
# Sex
# female                  NaN                          NaN  \
# male                    3.0                          3.0
#
# Name    Abbott, Mrs. Stanton (Rosa Hunt)  Abelson, Mr. Samuel
# Sex
# female                               3.0                  NaN  \
# male                                 NaN                  2.0
#
# Name    Abelson, Mrs. Samuel (Hannah Wizosky)  Adahl, Mr. Mauritz Nils Martin
# Sex
# female                                    2.0                             NaN  \
# male                                      NaN                             3.0
#
# Name    Adams, Mr. John  Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# Sex
# female              NaN                                             3.0  \
# male                3.0                                             NaN
#
# Name    Aks, Mrs. Sam (Leah Rosen)  Albimona, Mr. Nassef Cassem  ...
# ...

# %%
df.pivot_table(values = 'Pclass', index = 'Sex', columns = 'Name',fill_value= 0, margins = True)
# Out:
# Name    Abbing, Mr. Anthony  Abbott, Mr. Rossmore Edward
# Sex
# female                    0                            0  \
# male                      3                            3
# All                       3                            3
#
# Name    Abbott, Mrs. Stanton (Rosa Hunt)  Abelson, Mr. Samuel
# Sex
# female                                 3                    0  \
# male                                   0                    2
# All                                    3                    2
#
# Name    Abelson, Mrs. Samuel (Hannah Wizosky)  Adahl, Mr. Mauritz Nils Martin
# Sex
# female                                      2                               0  \
# male                                        0                               3
# All                                         2                               3
#
# Name    Adams, Mr. John  Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# Sex
# ...

# %%
df_idn = df.set_index('Name')
print(df_idn)
# Out:
#                                                     PassengerId  Survived
# Name
# Braund, Mr. Owen Harris                                       1         0  \
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
#                                                     Pclass     Sex   Age
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import matplotlib.pyplot as plt

df[df['Sex']=='male']['Pclass'].hist(alpha=0.9,bins=20)
df[df['Sex']=='female']['Pclass'].hist(alpha=0.7,bins=20)

plt.legend(['male','female'])
plt.show()

# %%
df.pivot(index='Name',columns='Sex',values=['Pclass','Embarked'])
# Out:
#                                       Pclass      Embarked
# Sex                                   female male   female male
# Name
# Abbing, Mr. Anthony                      NaN    3      NaN    S
# Abbott, Mr. Rossmore Edward              NaN    3      NaN    S
# Abbott, Mrs. Stanton (Rosa Hunt)           3  NaN        S  NaN
# Abelson, Mr. Samuel                      NaN    2      NaN    C
# Abelson, Mrs. Samuel (Hannah Wizosky)      2  NaN        C  NaN
# ...                                      ...  ...      ...  ...
# de Mulder, Mr. Theodore                  NaN    3      NaN    S
# de Pelsmaeker, Mr. Alfons                NaN    3      NaN    S
# del Carlo, Mr. Sebastiano                NaN    2      NaN    C
# van Billiard, Mr. Austin Blyler          NaN    3      NaN    S
# van Melkebeke, Mr. Philemon              NaN    3      NaN    S
#
# [891 rows x 4 columns]
